# %%
file = open("Files/myfile.txt","a")
file.write("LA GRANDEE for BBA \n")
if file.writable():
    print("File is writable")
else:
    print("File is not writable")
file.close()
# Out:
# File is writable

# %%
file = open("Files/myfile.txt","r")
content= file.read()
print(content)
file.close()
# Out:
# "LA GRANDEE International College"LA GRANDEE for BBA
